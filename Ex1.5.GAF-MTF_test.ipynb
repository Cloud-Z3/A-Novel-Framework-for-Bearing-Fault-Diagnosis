# %%
# 读取谷歌云盘的数据请求
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/drive', force_remount=False)
# Out:
# Mounted at /content/drive

# %%
# !pip install pyts
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.5 MB 5.1 MB/s
# ...

# %%
# focus on file
# '12k Drive End Bearing Fault Data'
# '12k Fan End Bearing Fault Data'
# '48k Drive End Bearing Fault Data'

import os, sys
import random

import scipy.io as io
import seaborn
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from tqdm import tqdm
# from function_lab import *
from pyts.image import GramianAngularField
from pyts.image import MarkovTransitionField


for setting in ['12k Drive End Bearing Fault Data', '12k Fan End Bearing Fault Data', '48k Drive End Bearing Fault Data']:

    print(setting)

    rootpath1 = '/content/drive/MyDrive/Colab Notebooks/Bearing Fault Diagnosis/Data for testing/Time Series/' + setting
    rootpath2 = '/content/drive/MyDrive/Colab Notebooks/Bearing Fault Diagnosis/Data for testing/GAF-MTF/' + setting

    datafiles=os.listdir(rootpath1)

    for file in tqdm(datafiles):

        data=io.loadmat(os.path.join(rootpath1,file))['data'].reshape(1,-1)

        # GAF
        # print(file)
        gasf = GramianAngularField(image_size=256, method='difference')
        GAFdata = gasf.fit_transform(data)

        # MTF
        # print(file)
        mtf = MarkovTransitionField(image_size=256)
        MTFdata = mtf.fit_transform(data)

        io.savemat(os.path.join(rootpath2,file),{'GAF':GAFdata, 'MTF':MTFdata})
# Out:
# 12k Drive End Bearing Fault Data
# 100%|██████████| 14300/14300 [12:02<00:00, 19.79it/s]
# 12k Fan End Bearing Fault Data
# 100%|██████████| 11700/11700 [10:57<00:00, 17.80it/s]
# 48k Drive End Bearing Fault Data
#  94%|█████████▍| 11002/11700 [13:32<00:39, 17.50it/s]
